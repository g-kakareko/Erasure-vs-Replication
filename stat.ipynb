# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
from scipy.stats import lognorm
import matplotlib
import numpy as np

from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score
from scipy import stats
from scipy.stats import norm
from sklearn.metrics import r2_score

# %%
font = {'family' : 'normal',
        'size'   : 16}

matplotlib.rc('font', **font)

# %%
csv_fname = 'res_csv/rep_small.csv'
pd_rep_small = pd.read_csv(csv_fname) 

csv_fname = 'res_csv/rep_med.csv'
pd_rep_med = pd.read_csv(csv_fname)

csv_fname = 'res_csv/rep_large.csv'
pd_rep_large = pd.read_csv(csv_fname)

csv_fname = 'res_csv/jes_small.csv'
pd_jes_small = pd.read_csv(csv_fname)

csv_fname = 'res_csv/jes_med.csv'
pd_jes_med = pd.read_csv(csv_fname)

csv_fname = 'res_csv/jes_large.csv'
pd_jes_large = pd.read_csv(csv_fname)

# %%
v_1 = np.array(len(pd_rep_small['time'])*[1])
v_25 = np.array(len(pd_rep_small['time'])*[25])
v_200 = np.array(len(pd_rep_small['time'])*[200])

# %%
# Figure 1a- replication small
x = pd_rep_small['time']
print(min(x),max(x))
num_bins = 10
n, bins, patches = plt.hist(x, num_bins, normed=False, facecolor='blue', alpha=0.2)
plt.xlabel('Time [sec]')
plt.ylabel('Frequency')
# Tweak spacing to prevent clipping of ylabel
# axes = plt.gca()
# axes.set_xlim([0,0.2])
# axes.set_ylim([0,10])
fig = plt.gcf()
fig.set_size_inches(7.6, 7.6)
fig.savefig('figures/fig_1a_rs_hist.png', dpi=300)
plt.show()
# Out:
# 0.004 0.013000000000000001
# C:\Users\Grzegorz\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\Grzegorz\Anaconda3\lib\site-packages\matplotlib\font_manager.py:1331: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
# Figure 1b- replication med
x = pd_rep_med['time']
print(min(x),max(x))
num_bins = 10
n, bins, patches = plt.hist(x, num_bins, normed=False, facecolor='green', alpha=0.2)
plt.xlabel('Time [sec]')
plt.ylabel('Frequency')
# Tweak spacing to prevent clipping of ylabel
# axes = plt.gca()
# axes.set_xlim([0,0.2])
# axes.set_ylim([0,10])
fig = plt.gcf()
fig.set_size_inches(7.6, 7.6)
fig.savefig('figures/fig_1b_rm_hist.png', dpi=300)
plt.show()
# Out:
# 0.10800000000000001 0.7070000000000001
# C:\Users\Grzegorz\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\Grzegorz\Anaconda3\lib\site-packages\matplotlib\font_manager.py:1331: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
# Figure 1c- replication large
x = pd_rep_large['time']
print(min(x),max(x))
num_bins = 10
n, bins, patches = plt.hist(x, num_bins, normed=False, facecolor='red', alpha=0.2)
plt.xlabel('Time [sec]')
plt.ylabel('Frequency')
# Tweak spacing to prevent clipping of ylabel
# axes = plt.gca()
# axes.set_xlim([0,0.2])
# axes.set_ylim([0,10])
fig = plt.gcf()
fig.set_size_inches(7.6, 7.6)
fig.savefig('figures/fig_1b_rl_hist.png', dpi=300)
plt.show()
# Out:
# 0.33899999999999997 1.335
# C:\Users\Grzegorz\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\Grzegorz\Anaconda3\lib\site-packages\matplotlib\font_manager.py:1331: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
# Figure 2a- jes small
x = pd_jes_small['time']
print(min(x),max(x))
num_bins = 10
n, bins, patches = plt.hist(x, num_bins, normed=False, facecolor='blue', alpha=0.2)
plt.xlabel('Time [sec]')
plt.ylabel('Frequency')
# Tweak spacing to prevent clipping of ylabel
# axes = plt.gca()
# axes.set_xlim([0,0.2])
# axes.set_ylim([0,10])
fig = plt.gcf()
fig.set_size_inches(7.6, 7.6)
fig.savefig('figures/fig_2a_jes_hist.png', dpi=300)
plt.show()
# Out:
# 0.026000000000000002 0.075
# C:\Users\Grzegorz\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\Grzegorz\Anaconda3\lib\site-packages\matplotlib\font_manager.py:1331: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
# Figure 2b- jes med
x = pd_jes_med['time']
print(min(x),max(x))
num_bins = 10
n, bins, patches = plt.hist(x, num_bins, normed=False, facecolor='green', alpha=0.2)
plt.xlabel('Time [sec]')
plt.ylabel('Frequency')
# Tweak spacing to prevent clipping of ylabel
# axes = plt.gca()
# axes.set_xlim([0,0.2])
# axes.set_ylim([0,10])
fig = plt.gcf()
fig.set_size_inches(7.6, 7.6)
fig.savefig('figures/fig_2b_jes_hist.png', dpi=300)
plt.show()
# Out:
# 0.113 0.93
# C:\Users\Grzegorz\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\Grzegorz\Anaconda3\lib\site-packages\matplotlib\font_manager.py:1331: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
# Figure 2c- jes large
x = pd_jes_large['time']
print(min(x),max(x))
num_bins = 10
n, bins, patches = plt.hist(x, num_bins, normed=False, facecolor='red', alpha=0.2)
plt.xlabel('Time [sec]')
plt.ylabel('Frequency')
# Tweak spacing to prevent clipping of ylabel
# axes = plt.gca()
# axes.set_xlim([0,0.2])
# axes.set_ylim([0,10])
fig = plt.gcf()
fig.set_size_inches(7.6, 7.6)
fig.savefig('figures/fig_2c_jes_hist.png', dpi=300)
plt.show()
# Out:
# 0.71 4.218
# C:\Users\Grzegorz\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\Grzegorz\Anaconda3\lib\site-packages\matplotlib\font_manager.py:1331: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
# Figure 3a- replication small
t1 = pd_rep_small['time']
t25 = pd_rep_med['time']
t200 = pd_rep_large['time']
# v_1
# v_25
# v_200
plt.scatter(v_1, t1, edgecolor="k", s=80, color='blue')
plt.scatter(v_25, t25, edgecolor="k", s=80, color='green')
plt.scatter(v_200, t200, edgecolor="k", s=80, color='red')

plt.legend(['small', 'medium', 'large'], loc='upper left')
plt.xlabel('Size [MB]')
plt.ylabel('Time [sec]')
# Tweak spacing to prevent clipping of ylabel
# axes = plt.gca()
# axes.set_xlim([0,0.2])
# axes.set_ylim([0,10])
fig = plt.gcf()
fig.set_size_inches(7.6, 7.6)
fig.savefig('figures/fig_3a_rep.png', dpi=300)
plt.show()
# Out:
# C:\Users\Grzegorz\Anaconda3\lib\site-packages\matplotlib\font_manager.py:1331: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
# Figure 4- jes
t1 = pd_jes_small['time']
t25 = pd_jes_med['time']
t200 = pd_jes_large['time']
# v_1
# v_25
# v_200
# plt.scatter(np.log(v_1), np.log(t1), edgecolor="k", s=80, color='blue')
# plt.scatter(np.log(v_25), np.log(t25), edgecolor="k", s=80, color='green')
# plt.scatter(np.log(v_200), np.log(t200), edgecolor="k", s=80, color='red')

plt.scatter(v_1, t1, edgecolor="k", s=80, color='blue')
plt.scatter(v_25, t25, edgecolor="k", s=80, color='green')
plt.scatter(v_200, t200, edgecolor="k", s=80, color='red')


plt.legend(['small', 'medium', 'large'], loc='upper left')
plt.xlabel('Size [MB]')
plt.ylabel('Time [sec]')
# Tweak spacing to prevent clipping of ylabel
# axes = plt.gca()
# axes.set_xlim([0,0.2])
# axes.set_ylim([0,10])
fig = plt.gcf()
fig.set_size_inches(7.6, 7.6)
fig.savefig('figures/fig_4_js.png', dpi=300)
plt.show()
# Out:
# C:\Users\Grzegorz\Anaconda3\lib\site-packages\matplotlib\font_manager.py:1331: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
# Figure 5- replication small
t1 = pd_rep_small['time']
t25 = pd_rep_med['time']
t200 = pd_rep_large['time']

s1 = pd_rep_small['memory']/1000
s25 = pd_rep_med['memory']/1000
s200 = pd_rep_large['memory']/1000
# v_1
# v_25
# v_200
# plt.scatter(s1,t1, edgecolor="k", s=80, color='blue')
# plt.scatter(s25, t25, edgecolor="k", s=80, color='green')
# plt.scatter(s200, t200, edgecolor="k", s=80, color='red')

plt.scatter(s1,t1, edgecolor="k", s=80, color='blue')
plt.scatter(s25, t25, edgecolor="k", s=80, color='green')
plt.scatter(s200, t200, edgecolor="k", s=80, color='red')

plt.legend(['small', 'medium', 'large'], loc='upper left')
plt.xlabel('Size [MB]')
plt.ylabel('Time [sec]')
# Tweak spacing to prevent clipping of ylabel
# axes = plt.gca()
# axes.set_xlim([0,0.2])
# axes.set_ylim([0,10])
fig = plt.gcf()
fig.set_size_inches(7.6, 7.6)
fig.savefig('figures/fig_5_rep.png', dpi=300)
plt.show()

# %%
# Out:
# C:\Users\Grzegorz\Anaconda3\lib\site-packages\matplotlib\font_manager.py:1331: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
# Figure 6- replication small
t1 = pd_jes_small['time']
t25 = pd_jes_med['time']
t200 = pd_jes_large['time']

s1 = pd_jes_small['memory']/1000
s25 = pd_jes_med['memory']/1000
s200 = pd_jes_large['memory']/1000
# v_1
# v_25
# v_200
# plt.scatter(s1,t1, edgecolor="k", s=80, color='blue')
# plt.scatter(s25, t25, edgecolor="k", s=80, color='green')
# plt.scatter(s200, t200, edgecolor="k", s=80, color='red')

plt.scatter(s1,t1, edgecolor="k", s=80, color='blue')
plt.scatter(s25, t25, edgecolor="k", s=80, color='green')
plt.scatter(s200, t200, edgecolor="k", s=80, color='red')

plt.legend(['small', 'medium', 'large'], loc='upper left')
plt.xlabel('Size [MB]')
plt.ylabel('Time [sec]')
# Tweak spacing to prevent clipping of ylabel
# axes = plt.gca()
# axes.set_xlim([0,0.2])
# axes.set_ylim([0,10])
fig = plt.gcf()
fig.set_size_inches(7.6, 7.6)
fig.savefig('figures/fig_6_rep.png', dpi=300)
plt.show()
# Out:
# C:\Users\Grzegorz\Anaconda3\lib\site-packages\matplotlib\font_manager.py:1331: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
print(np.mean(s1))
print(np.mean(s25))
print(np.mean(s200))

# %%
# Figure 7- replication regression
t1 = pd_rep_small['time']
t25 = pd_rep_med['time']
t200 = pd_rep_large['time']

x_reg = np.concatenate([v_1, v_25, v_200], axis=0)
y_reg = np.concatenate([t1, t25, t200], axis=0)

slope, intercept, r_value, p_value, std_err = stats.linregress(x_reg, y_reg)
# print(slope, intercept, r_value, p_value, std_err, r_value**2)
print(r_value,r_value**2)
# x_p = np.array([1, 25,200])
x_p = np.arange(1,200)
y_p = slope*x_p + intercept 

plt.scatter(v_1, t1, edgecolor="k", s=80, color='blue')
plt.scatter(v_25, t25, edgecolor="k", s=80, color='green')
plt.scatter(v_200, t200, edgecolor="k", s=80, color='red')
plt.plot(x_p, y_p,'r--', linewidth=2.0)

plt.legend(['lin reg','small', 'medium', 'large'], loc='upper left')
plt.xlabel('Size [MB]')
plt.ylabel('Time [sec]')
# Tweak spacing to prevent clipping of ylabel
# axes = plt.gca()
# axes.set_xlim([0,0.2])
# axes.set_ylim([0,10])
fig = plt.gcf()
fig.set_size_inches(7.6, 7.6)
fig.savefig('figures/fig_5.png', dpi=300)
plt.show()

y_pp = slope*x_reg + intercept 
error = y_pp - y_reg
plt.scatter(x_reg, error,marker='x', s=80, color='red')
plt.xlabel('Size [MB]')
plt.ylabel('error [sec]')
fig = plt.gcf()
fig.set_size_inches(7.6, 7.6)
fig.savefig('figures/fig_6.png', dpi=300)
plt.show()

i_vec = np.arange(1, len(x_reg)+1)
qi = np.array([(i-0.5)/len(i_vec) for i in i_vec])
zscore = norm.ppf(qi)
z = np.polyfit(zscore, np.sort(error), 1) 
p = np.poly1d(z)
y_pol = p(np.sort(zscore))

plt.plot(zscore, y_pol,'b--', linewidth=2.0)
# zscore
plt.scatter(zscore, np.sort(error),marker='x', s=80, color='red')
plt.xlabel('zscore')
plt.ylabel('error [sec]')
fig = plt.gcf()
fig.set_size_inches(7.6, 7.6)
fig.savefig('figures/fig_7.png', dpi=300)
plt.show()
print('r2 score: ', r2_score(y_pp, y_reg))
# Out:
# 0.9101701703533731 0.8284097390010883
# C:\Users\Grzegorz\Anaconda3\lib\site-packages\matplotlib\font_manager.py:1331: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# r2 score:  0.7928678853947105

# %%
# Figure 7- replication regression
t1 = pd_jes_small['time']
t25 = pd_jes_med['time']
t200 = pd_jes_large['time']

x_reg = np.concatenate([v_1, v_25, v_200], axis=0)
y_reg = np.concatenate([t1, t25, t200], axis=0)

slope, intercept, r_value, p_value, std_err = stats.linregress(x_reg, y_reg)
# print(slope, intercept, r_value, p_value, std_err, r_value**2)
print(r_value,  r_value**2)
# x_p = np.array([1, 25,200])
x_p = np.arange(1,200)
y_p = slope*x_p + intercept 

plt.scatter(v_1, t1, edgecolor="k", s=80, color='blue')
plt.scatter(v_25, t25, edgecolor="k", s=80, color='green')
plt.scatter(v_200, t200, edgecolor="k", s=80, color='red')
plt.plot(x_p, y_p,'r--', linewidth=2.0)

plt.legend(['lin reg','small', 'medium', 'large'], loc='upper left')
plt.xlabel('Size [MB]')
plt.ylabel('Time [sec]')
# Tweak spacing to prevent clipping of ylabel
# axes = plt.gca()
# axes.set_xlim([0,0.2])
# axes.set_ylim([0,10])
fig = plt.gcf()
fig.set_size_inches(7.6, 7.6)
fig.savefig('figures/fig_8.png', dpi=300)
plt.show()

y_pp = slope*x_reg + intercept 
error = y_pp - y_reg
plt.scatter(x_reg, error,marker='x', s=80, color='red')
plt.xlabel('Size [MB]')
plt.ylabel('error [sec]')
fig = plt.gcf()
fig.set_size_inches(7.6, 7.6)
fig.savefig('figures/fig_9.png', dpi=300)
plt.show()

i_vec = np.arange(1, len(x_reg)+1)
qi = np.array([(i-0.5)/len(i_vec) for i in i_vec])
zscore = norm.ppf(qi)
z = np.polyfit(zscore, np.sort(error), 1) 
p = np.poly1d(z)
y_pol = p(np.sort(zscore))

plt.plot(zscore, y_pol,'b--', linewidth=2.0)
# zscore
plt.scatter(zscore, np.sort(error),marker='x', s=80, color='red')
plt.xlabel('zscore')
plt.ylabel('error [sec]')
fig = plt.gcf()
fig.set_size_inches(7.6, 7.6)
fig.savefig('figures/fig_10.png', dpi=300)
plt.show()
print('r2 score: ', r2_score(y_pp, y_reg))
# Out:
# 0.8020023425172232 0.6432077574031134
# C:\Users\Grzegorz\Anaconda3\lib\site-packages\matplotlib\font_manager.py:1331: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# r2 score:  0.4452923826083821

# %%
# y = A + B log x
# z_log = np.polyfit(np.log(x_reg), y_reg, 1)
# y_log = z_log[0]*np.log(x_p) + z_log[1]

t1 = pd_rep_small['time']
t25 = pd_rep_med['time']
t200 = pd_rep_large['time']

x_reg = np.concatenate([v_1, v_25, v_200], axis=0)
y_reg = np.concatenate([t1, t25, t200], axis=0)

# slope, intercept, r_value, p_value, std_err = stats.linregress(x_reg, y_reg)
# print(slope, intercept, r_value, p_value, std_err, r_value**2)
z_log = np.polyfit(np.log(x_reg), y_reg, 1)


# x_p = np.array([1, 25,200])
x_p = np.arange(1,200)
# y_p = slope*x_p + intercept 
y_p = z_log[0]*np.log(x_p) + z_log[1]

plt.scatter(v_1, t1, edgecolor="k", s=80, color='blue')
plt.scatter(v_25, t25, edgecolor="k", s=80, color='green')
plt.scatter(v_200, t200, edgecolor="k", s=80, color='red')
plt.plot(x_p, y_p,'r--', linewidth=2.0)

plt.legend(['log reg','small', 'medium', 'large'], loc='upper left')
plt.xlabel('Size [MB]')
plt.ylabel('Time [sec]')
# Tweak spacing to prevent clipping of ylabel
# axes = plt.gca()
# axes.set_xlim([0,0.2])
# axes.set_ylim([0,10])
fig = plt.gcf()
fig.set_size_inches(7.6, 7.6)
fig.savefig('figures/fig_11.png', dpi=300)
plt.show()

# y_pp = slope*x_reg + intercept 
y_pp = z_log[0]*np.log(x_reg) + z_log[1]
error = y_pp - y_reg
plt.scatter(x_reg, error,marker='x', s=80, color='red')
plt.xlabel('Size [MB]')
plt.ylabel('error [sec]')
fig = plt.gcf()
fig.set_size_inches(7.6, 7.6)
fig.savefig('figures/fig_12.png', dpi=300)
plt.show()

i_vec = np.arange(1, len(x_reg)+1)
qi = np.array([(i-0.5)/len(i_vec) for i in i_vec])
zscore = norm.ppf(qi)
z = np.polyfit(zscore, np.sort(error), 1) 
p = np.poly1d(z)
y_pol = p(np.sort(zscore))

plt.plot(zscore, y_pol,'b--', linewidth=2.0)
# zscore
plt.scatter(zscore, np.sort(error),marker='x', s=80, color='red')
plt.xlabel('zscore')
plt.ylabel('error [sec]')
fig = plt.gcf()
fig.set_size_inches(7.6, 7.6)
fig.savefig('figures/fig_13.png', dpi=300)
plt.show()
print('r2 score: ', r2_score(y_pp, y_reg))
# Out:
# C:\Users\Grzegorz\Anaconda3\lib\site-packages\matplotlib\font_manager.py:1331: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# r2 score:  0.7239860258275904

# %%
# y = A + B log x
# z_log = np.polyfit(np.log(x_reg), y_reg, 1)
# y_log = z_log[0]*np.log(x_p) + z_log[1]

t1 = pd_jes_small['time']
t25 = pd_jes_med['time']
t200 = pd_jes_large['time']

x_reg = np.concatenate([v_1, v_25, v_200], axis=0)
y_reg = np.concatenate([t1, t25, t200], axis=0)

# slope, intercept, r_value, p_value, std_err = stats.linregress(x_reg, y_reg)
# print(slope, intercept, r_value, p_value, std_err, r_value**2)
z_log = np.polyfit(np.log(x_reg), y_reg, 1)


# x_p = np.array([1, 25,200])
x_p = np.arange(1,200)
# y_p = slope*x_p + intercept 
y_p = z_log[0]*np.log(x_p) + z_log[1]

plt.scatter(v_1, t1, edgecolor="k", s=80, color='blue')
plt.scatter(v_25, t25, edgecolor="k", s=80, color='green')
plt.scatter(v_200, t200, edgecolor="k", s=80, color='red')
plt.plot(x_p, y_p,'r--', linewidth=2.0)

plt.legend(['log reg','small', 'medium', 'large'], loc='upper left')
plt.xlabel('Size [MB]')
plt.ylabel('Time [sec]')
# Tweak spacing to prevent clipping of ylabel
# axes = plt.gca()
# axes.set_xlim([0,0.2])
# axes.set_ylim([0,10])
fig = plt.gcf()
fig.set_size_inches(7.6, 7.6)
fig.savefig('figures/fig_14.png', dpi=300)
plt.show()

# y_pp = slope*x_reg + intercept 
y_pp = z_log[0]*np.log(x_reg) + z_log[1]
error = y_pp - y_reg
plt.scatter(x_reg, error,marker='x', s=80, color='red')
plt.xlabel('Size [MB]')
plt.ylabel('error [sec]')
fig = plt.gcf()
fig.set_size_inches(7.6, 7.6)
fig.savefig('figures/fig_15.png', dpi=300)
plt.show()

i_vec = np.arange(1, len(x_reg)+1)
qi = np.array([(i-0.5)/len(i_vec) for i in i_vec])
zscore = norm.ppf(qi)
z = np.polyfit(zscore, np.sort(error), 1) 
p = np.poly1d(z)
y_pol = p(np.sort(zscore))

plt.plot(zscore, y_pol,'b--', linewidth=2.0)
# zscore
plt.scatter(zscore, np.sort(error),marker='x', s=80, color='red')
plt.xlabel('zscore')
plt.ylabel('error [sec]')
fig = plt.gcf()
fig.set_size_inches(7.6, 7.6)
fig.savefig('figures/fig_16.png', dpi=300)
plt.show()
print('r2 score: ', r2_score(y_pp, y_reg))
# Out:
# C:\Users\Grzegorz\Anaconda3\lib\site-packages\matplotlib\font_manager.py:1331: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# r2 score:  0.004574290581480955

# %%
# y = A + B log x
# z_log = np.polyfit(np.log(x_reg), y_reg, 1)
# y_log = z_log[0]*np.log(x_p) + z_log[1]

t1 = pd_rep_small['time']
t25 = pd_rep_med['time']
t200 = pd_rep_large['time']

x_reg = np.concatenate([v_1, v_25, v_200], axis=0)
y_reg = np.concatenate([t1, t25, t200], axis=0)

# slope, intercept, r_value, p_value, std_err = stats.linregress(x_reg, y_reg)
# print(slope, intercept, r_value, p_value, std_err, r_value**2)
# z_log = np.polyfit(np.log(x_reg), y_reg, 1)

# x_p = np.array([1, 25,200])
x_p = np.arange(1,200)
# y_p = slope*x_p + intercept 
z = np.polyfit(x_reg, y_reg, 2) 
p = np.poly1d(z)
y_p = p(x_p)

plt.scatter(v_1, t1, edgecolor="k", s=80, color='blue')
plt.scatter(v_25, t25, edgecolor="k", s=80, color='green')
plt.scatter(v_200, t200, edgecolor="k", s=80, color='red')
plt.plot(x_p, y_p,'r--', linewidth=2.0)

plt.legend(['pol reg','small', 'medium', 'large'], loc='upper left')
plt.xlabel('Size [MB]')
plt.ylabel('Time [sec]')
# Tweak spacing to prevent clipping of ylabel
# axes = plt.gca()
# axes.set_xlim([0,0.2])
# axes.set_ylim([0,10])
fig = plt.gcf()
fig.set_size_inches(7.6, 7.6)
fig.savefig('figures/fig_17.png', dpi=300)
plt.show()

# y_pp = slope*x_reg + intercept 
y_pp = z_log[0]*np.log(x_reg) + z_log[1]
error = y_pp - y_reg
plt.scatter(x_reg, error,marker='x', s=80, color='red')
plt.xlabel('Size [MB]')
plt.ylabel('error [sec]')
fig = plt.gcf()
fig.set_size_inches(7.6, 7.6)
fig.savefig('figures/fig_18.png', dpi=300)
plt.show()

i_vec = np.arange(1, len(x_reg)+1)
qi = np.array([(i-0.5)/len(i_vec) for i in i_vec])
zscore = norm.ppf(qi)
z = np.polyfit(zscore, np.sort(error), 1) 
p = np.poly1d(z)
y_pol = p(np.sort(zscore))

plt.plot(zscore, y_pol,'b--', linewidth=2.0)
# zscore
plt.scatter(zscore, np.sort(error),marker='x', s=80, color='red')
plt.xlabel('zscore')
plt.ylabel('error [sec]')
fig = plt.gcf()
fig.set_size_inches(7.6, 7.6)
fig.savefig('figures/fig_19.png', dpi=300)
plt.show()
print('r2 score: ', r2_score(y_pp, y_reg))
# Out:
# C:\Users\Grzegorz\Anaconda3\lib\site-packages\matplotlib\font_manager.py:1331: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# r2 score:  0.5128148707824398

# %%
# y = A + B log x
# z_log = np.polyfit(np.log(x_reg), y_reg, 1)
# y_log = z_log[0]*np.log(x_p) + z_log[1]

t1 = pd_jes_small['time']
t25 = pd_jes_med['time']
t200 = pd_jes_large['time']

x_reg = np.concatenate([v_1, v_25, v_200], axis=0)
y_reg = np.concatenate([t1, t25, t200], axis=0)

# slope, intercept, r_value, p_value, std_err = stats.linregress(x_reg, y_reg)
# print(slope, intercept, r_value, p_value, std_err, r_value**2)
# z_log = np.polyfit(np.log(x_reg), y_reg, 1)

# x_p = np.array([1, 25,200])
x_p = np.arange(1,200)
# y_p = slope*x_p + intercept 
z = np.polyfit(x_reg, y_reg, 2) 
p = np.poly1d(z)
y_p = p(x_p)

plt.scatter(v_1, t1, edgecolor="k", s=80, color='blue')
plt.scatter(v_25, t25, edgecolor="k", s=80, color='green')
plt.scatter(v_200, t200, edgecolor="k", s=80, color='red')
plt.plot(x_p, y_p,'r--', linewidth=2.0)

plt.legend(['pol reg','small', 'medium', 'large'], loc='upper left')
plt.xlabel('Size [MB]')
plt.ylabel('Time [sec]')
# Tweak spacing to prevent clipping of ylabel
# axes = plt.gca()
# axes.set_xlim([0,0.2])
# axes.set_ylim([0,10])
fig = plt.gcf()
fig.set_size_inches(7.6, 7.6)
fig.savefig('figures/fig_20.png', dpi=300)
plt.show()

# y_pp = slope*x_reg + intercept 
y_pp = z_log[0]*np.log(x_reg) + z_log[1]
error = y_pp - y_reg
plt.scatter(x_reg, error,marker='x', s=80, color='red')
plt.xlabel('Size [MB]')
plt.ylabel('error [sec]')
fig = plt.gcf()
fig.set_size_inches(7.6, 7.6)
fig.savefig('figures/fig_21.png', dpi=300)
plt.show()

i_vec = np.arange(1, len(x_reg)+1)
qi = np.array([(i-0.5)/len(i_vec) for i in i_vec])
zscore = norm.ppf(qi)
z = np.polyfit(zscore, np.sort(error), 1) 
p = np.poly1d(z)
y_pol = p(np.sort(zscore))

plt.plot(zscore, y_pol,'b--', linewidth=2.0)
# zscore
plt.scatter(zscore, np.sort(error),marker='x', s=80, color='red')
plt.xlabel('zscore')
plt.ylabel('error [sec]')
fig = plt.gcf()
fig.set_size_inches(7.6, 7.6)
fig.savefig('figures/fig_22.png', dpi=300)
plt.show()
print('r2 score: ', r2_score(y_pp, y_reg))
# Out:
# C:\Users\Grzegorz\Anaconda3\lib\site-packages\matplotlib\font_manager.py:1331: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# r2 score:  0.004574290581480955

# %%
# Figure 8- error replication regression
y_log = z_log[0]*np.log(x_reg) + z_log[1]
error = y_log - y_reg
plt.scatter(x_reg, error,marker='x', s=80, color='red')
plt.xlabel('Size [MB]')
plt.ylabel('error [sec]')
fig = plt.gcf()
fig.set_size_inches(7.6, 7.6)
fig.savefig('figures/fig_6.png', dpi=300)
plt.show()

# %%
# Figure 7- replication regression
t1 = pd_rep_small['time']
t25 = pd_rep_med['time']
t200 = pd_rep_large['time']

x_reg = np.concatenate([v_1, v_25, v_200], axis=0)
y_reg = np.concatenate([t1, t25, t200], axis=0)

slope, intercept, r_value, p_value, std_err = stats.linregress(x_reg, y_reg)
print(slope, intercept, r_value, p_value, std_err, r_value**2)
# x_p = np.array([1, 25,200])
x_p = np.arange(1,200)
y_p = slope*x_p + intercept 

z = np.polyfit(x_reg, y_reg, 2) 
p = np.poly1d(z)
y_pol = p(x_p)
# y = A + B log x
z_log = np.polyfit(np.log(x_reg), y_reg, 1)
y_log = z_log[0]*np.log(x_p) + z_log[1]
# Out:
# 0.003329843648484504 0.07739177848083406 0.9101701703533731 4.410097972957245e-116 8.778886400715576e-05 0.8284097390010883

# %%
plt.scatter(v_1, t1, edgecolor="k", s=80, color='blue')
plt.scatter(v_25, t25, edgecolor="k", s=80, color='green')
plt.scatter(v_200, t200, edgecolor="k", s=80, color='red')
plt.plot(x_p, y_p,'r--', linewidth=2.0)
plt.plot(x_p, y_pol,'b--', linewidth=2.0)
plt.plot(x_p, y_log,'g--', linewidth=2.0)

plt.legend(['lin reg','pol reg','log reg','small', 'medium', 'large'], loc='upper left')
plt.xlabel('Size [MB]')
plt.ylabel('Time [sec]')
# Tweak spacing to prevent clipping of ylabel
# axes = plt.gca()
# axes.set_xlim([0,0.2])
# axes.set_ylim([0,10])
fig = plt.gcf()
fig.set_size_inches(7.6, 7.6)
fig.savefig('figures/fig_7_rep_reg.png', dpi=300)
plt.show()
# Out:
# C:\Users\Grzegorz\Anaconda3\lib\site-packages\matplotlib\font_manager.py:1331: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
# Figure 8- error replication regression
y_log = z_log[0]*np.log(x_reg) + z_log[1]
error = y_log - y_reg
plt.scatter(x_reg, error,marker='x', s=80, color='red')
plt.xlabel('Size [MB]')
plt.ylabel('error [sec]')
fig = plt.gcf()
fig.set_size_inches(7.6, 7.6)
fig.savefig('figures/fig_8_rep_reg_error.png', dpi=300)
plt.show()
# Out:
# C:\Users\Grzegorz\Anaconda3\lib\site-packages\matplotlib\font_manager.py:1331: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
# Figure 9- q-q replication regression
i_vec = np.arange(1, len(x_reg)+1)
qi = np.array([(i-0.5)/len(i_vec) for i in i_vec])
zscore = norm.ppf(qi)

z = np.polyfit(zscore, np.sort(error), 1) 
p = np.poly1d(z)
y_pol = p(np.sort(zscore))

plt.plot(zscore, y_pol,'b--', linewidth=2.0)
# zscore
plt.scatter(zscore, np.sort(error),marker='x', s=80, color='red')
plt.xlabel('zscore')
plt.ylabel('error [sec]')
fig = plt.gcf()
fig.set_size_inches(7.6, 7.6)
fig.savefig('figures/fig_9_rep_qq.png', dpi=300)
plt.show()
# Out:
# C:\Users\Grzegorz\Anaconda3\lib\site-packages\matplotlib\font_manager.py:1331: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
np.sort
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-115-cbe1027480e9> in <module>()
#       4 zscore = norm.ppf(qi)
#       5 # zscore
# ----> 6 plt.scatter(zscore, np.sorted(error),marker='x', s=80, color='red')
#       7 plt.xlabel('Size [MB]')
#       8 plt.ylabel('error [sec]')
#
# AttributeError: module 'numpy' has no attribute 'sorted'

# %%
# Figure 10- replication regression
t1 = pd_jes_small['time']
t25 = pd_jes_med['time']
t200 = pd_jes_large['time']

x_reg = np.concatenate([v_1, v_25, v_200], axis=0)
y_reg = np.concatenate([t1, t25, t200], axis=0)

slope, intercept, r_value, p_value, std_err = stats.linregress(x_reg, y_reg)
print(slope, intercept, r_value, p_value, std_err, r_value**2)
# x_p = np.array([1, 25,200])
x_p = np.arange(1,200)
y_p = slope*x_p + intercept 

z = np.polyfit(x_reg, y_reg, 2) 
p = np.poly1d(z)
y_pol = p(x_p)
# y = A + B log x
z_log = np.polyfit(np.log(x_reg), y_reg, 1)
y_log = z_log[0]*np.log(x_p) + z_log[1]

plt.scatter(v_1, t1, edgecolor="k", s=80, color='blue')
plt.scatter(v_25, t25, edgecolor="k", s=80, color='green')
plt.scatter(v_200, t200, edgecolor="k", s=80, color='red')
plt.plot(x_p, y_p,'r--', linewidth=2.0)
plt.plot(x_p, y_pol,'b--', linewidth=2.0)
plt.plot(x_p, y_log,'g--', linewidth=2.0)

plt.legend(['lin reg','pol reg','log reg','small', 'medium', 'large'], loc='upper left')
plt.xlabel('Size [MB]')
plt.ylabel('Time [sec]')

fig = plt.gcf()
fig.set_size_inches(7.6, 7.6)
fig.savefig('figures/fig_9_jes_reg.png', dpi=300)
plt.show()
# Out:
# 0.006692761080195476 0.05845866529194088 0.8020023425172232 1.1732422090219675e-68 0.0002887548281211087 0.6432077574031134
# C:\Users\Grzegorz\Anaconda3\lib\site-packages\matplotlib\font_manager.py:1331: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
# Figure 11- error replication regression
y_log = z_log[0]*np.log(x_reg) + z_log[1]
error = y_log - y_reg
plt.scatter(x_reg, error,marker='x', s=80, color='red')
plt.xlabel('Size [MB]')
plt.ylabel('error [sec]')
fig = plt.gcf()
fig.set_size_inches(7.6, 7.6)
fig.savefig('figures/fig_11_rep_reg_error.png', dpi=300)
plt.show()
# Out:
# C:\Users\Grzegorz\Anaconda3\lib\site-packages\matplotlib\font_manager.py:1331: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
# Figure 12- q-q replication regression
i_vec = np.arange(1, len(x_reg)+1)
qi = np.array([(i-0.5)/len(i_vec) for i in i_vec])
zscore = norm.ppf(qi)

z = np.polyfit(zscore, np.sort(error), 1) 
p = np.poly1d(z)
y_pol = p(np.sort(zscore))

plt.plot(zscore, y_pol,'b--', linewidth=2.0)
# zscore
plt.scatter(zscore, np.sort(error),marker='x', s=80, color='red')
plt.xlabel('zscore')
plt.ylabel('error [sec]')
fig = plt.gcf()
fig.set_size_inches(7.6, 7.6)
fig.savefig('figures/fig_12_rep_qq.png', dpi=300)
plt.show()
# Out:
# C:\Users\Grzegorz\Anaconda3\lib\site-packages\matplotlib\font_manager.py:1331: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
